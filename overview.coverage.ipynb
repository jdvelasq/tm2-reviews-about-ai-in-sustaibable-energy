# %%
from techminer2.overview import coverage
from techminer2.refine.words import apply_thesaurus

# %% [markdown]
# # COVERAGE

# %%
apply_thesaurus(root_dir="./")

coverage(
    #
    # PARAMS:
    field="keywords",
    #
    # DATABASE_PARAMS
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).tail(20)
# Out:
# --INFO-- Applying `words.txt` thesaurus to author/index keywords and abstract/title words
# --INFO-- Number of documents : 539
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 539
#     min_occ  cum_sum_documents coverage  cum num items
# 24       20                436  80.89 %             41
# 25       19                444  82.37 %             44
# 26       18                452  83.86 %             49
# 27       17                458  84.97 %             51
# 28       16                460  85.34 %             54
# 29       15                469  87.01 %             64
# 30       14                470  87.20 %             69
# 31       13                471  87.38 %             77
# 32       12                477  88.50 %             87
# 33       11                483  89.61 %             94
# 34       10                490  90.91 %            117
# 35        9                493  91.47 %            135
# 36        8                497  92.21 %            154
# 37        7                502  93.14 %            180
# 38        6                510  94.62 %            211
# 39        5                514  95.36 %            274
# 40        4                520  96.47 %            377
# 41        3                523  97.03 %            539
# 42        2                527  97.77 %           1003
# 43        1                531  98.52 %           3768
