# %%
from techminer2.analyze import coverage

# %% [markdown]
# # COVERAGE

# %%
#
# article
#
for year in range(2011, 2023):
    print(f"---< {year} >" + "-" * 80)
    cov = coverage(
        #
        # PARAMS:
        field="author_keywords",
        #
        # DATABASE_PARAMS
        root_dir="./",
        database="main",
        year_filter=(year, year),
        cited_by_filter=(None, None),
    ).tail(15)
    print(cov)
    print()
# Out:
# ---< 2011 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 3
# --INFO--   Documents with NA : 1
# --INFO--  Efective documents : 2
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        1                  2  100.00 %              9
#
# ---< 2012 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 8
# --INFO--   Documents with NA : 1
# --INFO--  Efective documents : 7
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        2                  2   28.57 %              1
# 1        1                  7  100.00 %             31
#
# ---< 2013 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 5
# --INFO--   Documents with NA : 1
# --INFO--  Efective documents : 4
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        2                  2   50.00 %              1
# 1        1                  4  100.00 %             18
#
# ---< 2014 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 8
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 8
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        4                  4   50.00 %              1
# 1        3                  5   62.50 %              2
# 2        2                  5   62.50 %              3
# 3        1                  8  100.00 %             37
#
# ---< 2015 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 18
# --INFO--   Documents with NA : 1
# --INFO--  Efective documents : 17
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        6                  6   35.29 %              1
# 1        3                  7   41.18 %              2
# 2        2                 11   64.71 %              5
# 3        1                 17  100.00 %             81
#
# ---< 2016 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 15
# --INFO--   Documents with NA : 2
# --INFO--  Efective documents : 13
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        2                  2   15.38 %              1
# 1        1                 13  100.00 %             50
#
# ---< 2017 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 20
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 20
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        5                  5   25.00 %              1
# 1        4                  8   40.00 %              2
# 2        2                 13   65.00 %              7
# 3        1                 20  100.00 %             83
#
# ---< 2018 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 25
# --INFO--   Documents with NA : 2
# --INFO--  Efective documents : 23
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        3                  6   26.09 %              3
# 1        2                 15   65.22 %             11
# 2        1                 23  100.00 %             92
#
# ---< 2019 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 29
# --INFO--   Documents with NA : 5
# --INFO--  Efective documents : 24
#    min_occ  cum_sum_documents  coverage  cum num items
# 0        3                 12   50.00 %              6
# 1        2                 14   58.33 %             13
# 2        1                 24  100.00 %             89
#
# ---< 2020 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 47
# --INFO--   Documents with NA : 7
# --INFO--  Efective documents : 40
#    min_occ  cum_sum_documents coverage  cum num items
# 0        4                  8  20.00 %              2
# 1        3                 13  32.50 %              4
# 2        2                 29  72.50 %             19
# 3        1                 39  97.50 %            153
#
# ---< 2021 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 90
# --INFO--   Documents with NA : 13
# --INFO--  Efective documents : 77
#    min_occ  cum_sum_documents  coverage  cum num items
# 0       14                 14   18.18 %              1
# 1        8                 20   25.97 %              2
# 2        7                 24   31.17 %              3
# 3        6                 26   33.77 %              4
# 4        5                 30   38.96 %              5
# 5        4                 35   45.45 %              8
# 6        3                 45   58.44 %             18
# 7        2                 53   68.83 %             33
# 8        1                 77  100.00 %            281
#
# ---< 2022 >--------------------------------------------------------------------------------
# --INFO-- Number of documents : 119
# --INFO--   Documents with NA : 16
# --INFO--  Efective documents : 103
#     min_occ  cum_sum_documents  coverage  cum num items
# 0        15                 15   14.56 %              1
# 1        12                 25   24.27 %              2
# 2        11                 37   35.92 %              4
# 3        10                 49   47.57 %              6
# 4         8                 52   50.49 %              7
# 5         6                 56   54.37 %             10
# 6         5                 59   57.28 %             12
# 7         4                 60   58.25 %             13
# 8         3                 67   65.05 %             19
# 9         2                 81   78.64 %             47
# 10        1                103  100.00 %            325
