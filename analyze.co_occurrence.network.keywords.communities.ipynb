# %%
from techminer2.analyze.co_occurrence.network.keywords import (
    communities,
    communities_summary,
)
from techminer2.refine.words import apply_thesaurus
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'bayanpy', 'wurlitzer', 'infomap'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}

# %% [markdown]
# # COMMUNITIES

# %%
# apply_thesaurus(root_dir="./")

m = communities_summary(
    conserve_counters=False,
    top_n=None,
    occ_range=(5, None),
    algorithm_or_dict="louvain",
    association_index="association",
    root_dir="./",
    year_filter=(None, None),
)

m["Terms"] = m["Terms"].str.split("; ")
m["Terms"] = m["Terms"].map(lambda x: [t.strip() for t in x[:5]])
m["Terms"] = m["Terms"].str.join("; ")

print(m.to_markdown())
# Out:
# --INFO-- Applying `words.txt` thesaurus to author/index keywords and abstract/title words
# |    | Cluster   |   Num Terms |   Percentage | Terms                                                                                                              |
# |---:|:----------|------------:|-------------:|:-------------------------------------------------------------------------------------------------------------------|
# |  0 | CL_0      |          79 |         28.8 | ELECTRIC_POWER_TRANSMISSION_NETWORKS; SMART_POWER_GRIDS; ENERGY_EFFICIENCY; SMART_GRID; RENEWABLE_ENERGY_RESOURCES |
# |  1 | CL_1      |          73 |         26.6 | SOLAR_ENERGY; GENETIC_ALGORITHMS; SOLAR_POWER_GENERATION; PARTICLE_SWARM_OPTIMIZATION; PHOTOVOLTAIC_SYSTEMS        |
# |  2 | CL_2      |          48 |         17.5 | DEEP_LEARNING; ELECTRIC_VEHICLES; LITHIUM_ION_BATTERIES; CHARGING; DIGITAL_STORAGE                                 |
# |  3 | CL_3      |          47 |         17.2 | NEURAL_NETWORKS; SUPPORT_VECTOR_MACHINES; FOSSIL_FUELS; SUSTAINABLE_DEVELOPMENT; CLIMATE_CHANGE                    |
# |  4 | CL_4      |          27 |          9.9 | RENEWABLE_ENERGIES; WIND_POWER; WIND_TURBINES; RENEWABLE_ENERGY_SOURCE; FAULT_DETECTION                            |

# %%
communities(
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(5, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).head(20)
# Out:
#                                              CL_0  \
# 0   ELECTRIC_POWER_TRANSMISSION_NETWORKS 052:4249
# 1                      SMART_POWER_GRIDS 051:2990
# 2                      ENERGY_EFFICIENCY 048:3535
# 3                             SMART_GRID 048:2620
# 4             RENEWABLE_ENERGY_RESOURCES 042:3336
# 5                     ENERGY_UTILIZATION 037:3887
# 6                      ENERGY_MANAGEMENT 034:1091
# 7                        DECISION_MAKING 028:2098
# 8                 REINFORCEMENT_LEARNING 026:0952
# 9              ENERGY_MANAGEMENT_SYSTEMS 023:0717
# 10                            FUEL_CELLS 021:1515
# 11                             MICROGRID 017:0623
# 12                    INTERNET_OF_THINGS 016:0575
# 13                   MULTI_AGENT_SYSTEMS 015:0928
# 14                      ENERGY_RESOURCES 015:0835
# 15                    ELECTRIC_UTILITIES 015:0795
# 16                      GREENHOUSE_GASES 014:0490
# 17                              BIG_DATA 013:1084
# 18                                 POWER 013:0294
# 19                INFORMATION_MANAGEMENT 013:0146
#
#                                      CL_1  \
# 0                   SOLAR_ENERGY 048:4959
# 1             GENETIC_ALGORITHMS 044:4284
# 2         SOLAR_POWER_GENERATION 040:3184
# 3    PARTICLE_SWARM_OPTIMIZATION 031:1933
# 4           PHOTOVOLTAIC_SYSTEMS 029:2376
# 5                SOLAR_RADIATION 027:3465
# 6                  PHOTOVOLTAICS 027:0705
# 7                    FUZZY_LOGIC 026:2712
# 8                         ENERGY 025:1326
# 9                  OPTIMISATIONS 025:0641
# 10                   PERFORMANCE 022:1235
# 11  MAXIMUM_POWER_POINT_TRACKERS 021:1934
# 12          PARAMETER_ESTIMATION 020:1139
# 13                   CONTROLLERS 019:1219
# 14      META_HEURISTIC_ALGORITHM 019:1177
# 15             MEAN_SQUARE_ERROR 018:1399
# 16          HEURISTIC_ALGORITHMS 018:1148
# 17                HYBRID_SYSTEMS 015:2491
# 18  MAXIMUM_POWER_POINT_TRACKING 015:1272
# 19            PHOTOVOLTAIC_CELLS 015:1240
#
#                                      CL_2  \
# 0                  DEEP_LEARNING 081:3393
# 1              ELECTRIC_VEHICLES 036:1522
# 2          LITHIUM_ION_BATTERIES 033:0934
# 3                       CHARGING 031:1640
# 4                DIGITAL_STORAGE 024:0974
# 5     BATTERY_MANAGEMENT_SYSTEMS 022:0800
# 6                           IONS 021:0621
# 7                 ENERGY_STORAGE 019:0531
# 8                        CURRENT 017:0430
# 9            SECONDARY_BATTERIES 015:1025
# 10  CONVOLUTIONAL_NEURAL_NETWORK 014:0354
# 11     RECURRENT_NEURAL_NETWORKS 012:1022
# 12               STATE_OF_CHARGE 012:0611
# 13                  ELECTROLYTES 012:0435
# 14                CARBON_DIOXIDE 012:0127
# 15      RESEARCH_AND_DEVELOPMENT 011:0810
# 16              ELECTROCATALYSTS 011:0738
# 17        LONG_SHORT_TERM_MEMORY 011:0419
# 18            ELECTRIC_BATTERIES 010:0715
# 19               HYBRID_VEHICLES 010:0706
#
#                                       CL_3  \
# 0                 NEURAL_NETWORKS 100:9413
# 1         SUPPORT_VECTOR_MACHINES 034:3542
# 2                    FOSSIL_FUELS 026:1085
# 3         SUSTAINABLE_DEVELOPMENT 025:1476
# 4                  CLIMATE_CHANGE 018:0480
# 5                         BIOMASS 018:0305
# 6                  DECISION_TREES 016:1848
# 7                 NUMERICAL_MODEL 015:0456
# 8              ALTERNATIVE_ENERGY 014:1015
# 9                        BIOFUELS 014:0353
# 10           ENVIRONMENTAL_IMPACT 013:0351
# 11                  RANDOM_FOREST 010:0210
# 12  MACHINE_LEARNING_APPLICATIONS 010:0156
# 13                         CARBON 010:0125
# 14                  SUPPLY_CHAINS 010:0122
# 15   SUSTAINABLE_DEVELOPMENT_GOAL 009:0686
# 16            REGRESSION_ANALYSIS 009:0561
# 17                     LIFE_CYCLE 009:0512
# 18                  FUZZY_SYSTEMS 009:0355
# 19                      BIOENERGY 008:0325
#
#                                         CL_4
# 0                RENEWABLE_ENERGIES 074:4800
# 1                        WIND_POWER 046:2809
# 2                     WIND_TURBINES 026:1873
# 3           RENEWABLE_ENERGY_SOURCE 024:1435
# 4                   FAULT_DETECTION 022:1770
# 5                    ENERGY_SYSTEMS 022:1063
# 6        ARTIFICIAL_NEURAL_NETWORKS 018:2372
# 7                       WIND_ENERGY 016:0861
# 8                     ENERGY_POLICY 013:0588
# 9   HYBRID_RENEWABLE_ENERGY_SYSTEMS 012:0583
# 10             UNCERTAINTY_ANALYSIS 012:0386
# 11              TRADITIONAL_METHODS 010:1444
# 12             CONDITION_MONITORING 010:0996
# 13                   ENERGY_SOURCES 010:0662
# 14                ENERGY_CONVERSION 010:0638
# 15                        WIND_FARM 009:0640
# 16               ENERGY_FORECASTING 009:0490
# 17               SUSTAINABLE_ENERGY 008:0502
# 18                  FAULT_DIAGNOSIS 008:0117
# 19                             WIND 007:0228
