# %%
from techminer2.analyze.co_occurrence.network import (
    communities,
    communities_summary,
)
from techminer2.refine.words import apply_thesaurus
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'wurlitzer', 'infomap', 'bayanpy'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'ASLPAw', 'pyclustering'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}

# %% [markdown]
# # COMMUNITIES

# %%
apply_thesaurus(root_dir="./")

m = communities_summary(
    field='keywords',
    conserve_counters=False,
    top_n=None,
    occ_range=(5, None),
    algorithm_or_dict="louvain",
    association_index="association",
    root_dir="./",
    year_filter=(None, None),
)

m["Terms"] = m["Terms"].str.split("; ")
m["Terms"] = m["Terms"].map(lambda x: [t.strip() for t in x[:5]])
m["Terms"] = m["Terms"].str.join("; ")

print(m.to_markdown())
# Out:
# --INFO-- Applying `words.txt` thesaurus to author/index keywords and abstract/title words
# |    | Cluster   |   Num Terms |   Percentage | Terms                                                                                                      |
# |---:|:----------|------------:|-------------:|:-----------------------------------------------------------------------------------------------------------|
# |  0 | CL_0      |          81 |         32.3 | WIND_ENERGY; SOLAR_ENERGY; SOLAR_POWER_GENERATION; PHOTO_VOLTAIC_SYSTEM; PARTICLE_SWARM_OPTIMIZATION       |
# |  1 | CL_1      |          69 |         27.5 | SMART_GRID; ELECTRIC_POWER_TRANSMISSION_NETWORKS; ENERGY_EFFICIENCY; ENERGY_UTILIZATION; ENERGY_MANAGEMENT |
# |  2 | CL_2      |          45 |         17.9 | ARTIFICIAL_NEURAL_NETWORKS; GENETIC_ALGORITHMS; SUPPORT_VECTOR_MACHINES; DECISION_MAKING; FOSSIL_FUELS     |
# ...

# %%
communities(
    #
    # COLUMN PARAMS:
    field='keywords',
    top_n=None,
    occ_range=(5, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).head(50)
# Out:
#                                       CL_0  \
# 0                     WIND_ENERGY 049:2855
# 1                    SOLAR_ENERGY 048:4959
# 2          SOLAR_POWER_GENERATION 040:3184
# 3            PHOTO_VOLTAIC_SYSTEM 032:2708
# 4     PARTICLE_SWARM_OPTIMIZATION 031:1933
# 5                   PHOTO_VOLTAIC 030:0815
# 6                 SOLAR_RADIATION 027:3465
# 7                            MPPT 027:2087
# 8                     FUZZY_LOGIC 026:2712
# 9                   WIND_TURBINES 026:1873
# 10       META_HEURISTIC_ALGORITHM 024:1233
# 11                FAULT_DETECTION 022:1770
# 12                    PERFORMANCE 022:1235
# 13           PARAMETER_PREDICTION 021:1139
# 14           HEURISTIC_ALGORITHMS 018:1148
# 15             PHOTO_VOLTAIC_CELL 015:1240
# 16              COMPUTER_CIRCUITS 015:1229
# 17              MEAN_SQUARE_ERROR 015:1176
# 18                    SOLAR_CELLS 015:0615
# 19                NUMERICAL_MODEL 015:0456
# 20     SOLAR_RADIATION_PREDICTION 013:2588
# ...
