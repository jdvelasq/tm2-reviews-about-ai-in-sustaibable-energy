# %%
from techminer2.co_occurrence.network.thematic_map.keywords import communities_summary
from techminer2.co_occurrence.network.thematic_map.keywords import communities
from techminer2.refine.words import apply_thesaurus


# apply_thesaurus(root_dir="./")
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'infomap', 'wurlitzer', 'graph_tool', 'bayanpy'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'infomap', 'wurlitzer'}

# %% [markdown]
# # COMMUNITIES

# %%
m = communities_summary(
    conserve_counters=False,
    top_n=None,
    occ_range=(5, None),
    algorithm_or_dict="louvain",
    association_index="association",
    root_dir="./",
    year_filter=(None, None),
)

m['Terms'] = m['Terms'].str.split('; ')
m['Terms'] = m['Terms'].map(lambda x: [t.strip() for t in x[:5]])
m['Terms'] = m['Terms'].str.join("; ")

print(m.to_markdown())
# Out:
# |    | Cluster   |   Num Terms |   Percentage | Terms                                                                                                                 |
# |---:|:----------|------------:|-------------:|:----------------------------------------------------------------------------------------------------------------------|
# |  0 | CL_0      |          74 |         29   | SMART_GRID; ELECTRIC_POWER_TRANSMISSION_NETWORKS; ENERGY_EFFICIENCY; ENERGY_UTILIZATION; ENERGY_MANAGEMENT            |
# |  1 | CL_1      |          68 |         26.7 | LONG_SHORT_TERM_MEMORY_NETWORK; SOLAR_ENERGY; GENETIC_ALGORITHMS; SOLAR_POWER_GENERATION; PARTICLE_SWARM_OPTIMIZATION |
# |  2 | CL_2      |          48 |         18.8 | SUPPORT_VECTOR_MACHINES; DECISION_MAKING; FOSSIL_FUELS; SUSTAINABLE_DEVELOPMENT; OPTIMISATIONS                        |
# |  3 | CL_3      |          40 |         15.7 | DEEP_LEARNING; ELECTRIC_AND_HYBRID_VEHICLES; LITHIUM_BATTERIES; CHARGING_STRATEGIES; DIGITAL_STORAGE                  |
# |  4 | CL_4      |          25 |          9.8 | WIND_ENERGY; WIND_TURBINES; FUEL_CELL; ENERGY_SYSTEMS; ENERGY_POLICY                                                  |

# %%
communities(
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(5, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).head(20)
# Out:
#                                              CL_0  \
# 0                             SMART_GRID 059:3182
# 1   ELECTRIC_POWER_TRANSMISSION_NETWORKS 052:4249
# 2                      ENERGY_EFFICIENCY 048:3535
# 3                     ENERGY_UTILIZATION 037:3887
# 4                      ENERGY_MANAGEMENT 034:1091
# 5                 REINFORCEMENT_LEARNING 026:0952
# 6                                 ENERGY 024:1323
# 7              ENERGY_MANAGEMENT_SYSTEMS 023:0717
# 8                             MICRO_GRID 018:0632
# 9                     INTERNET_OF_THINGS 018:0590
# 10                   MULTI_AGENT_SYSTEMS 015:0928
# 11                      ENERGY_RESOURCES 015:0835
# 12                    ELECTRIC_UTILITIES 015:0795
# 13                              BIG_DATA 013:1084
# 14                           INVESTMENTS 013:0606
# 15                                 POWER 013:0294
# 16                INFORMATION_MANAGEMENT 013:0146
# 17                   ENERGY_CONSERVATION 012:0661
# 18         ELECTRIC_POWER_SYSTEM_CONTROL 012:0619
# 19                             BUILDINGS 011:0961
#
#                                        CL_1  \
# 0   LONG_SHORT_TERM_MEMORY_NETWORK 110:9831
# 1                     SOLAR_ENERGY 048:4959
# 2               GENETIC_ALGORITHMS 044:4284
# 3           SOLAR_POWER_GENERATION 040:3184
# 4      PARTICLE_SWARM_OPTIMIZATION 031:1933
# 5       ARTIFICIAL_NEURAL_NETWORKS 030:3294
# 6             PHOTO_VOLTAIC_SYSTEM 030:2683
# 7                    PHOTO_VOLTAIC 030:0815
# 8                  SOLAR_RADIATION 027:3465
# 9                             MPPT 027:2087
# 10                     FUZZY_LOGIC 026:2712
# 11        META_HEURISTIC_ALGORITHM 024:1233
# 12                 FAULT_DETECTION 022:1770
# 13                     PERFORMANCE 022:1235
# 14            PARAMETER_PREDICTION 021:1139
# 15                     CONTROLLERS 019:1219
# 16            HEURISTIC_ALGORITHMS 018:1148
# 17              PHOTO_VOLTAIC_CELL 015:1240
# 18               COMPUTER_CIRCUITS 015:1229
# 19               MEAN_SQUARE_ERROR 015:1176
#
#                                       CL_2  \
# 0         SUPPORT_VECTOR_MACHINES 034:3542
# 1                 DECISION_MAKING 028:2098
# 2                    FOSSIL_FUELS 026:1085
# 3         SUSTAINABLE_DEVELOPMENT 025:1476
# 4                   OPTIMISATIONS 025:0641
# 5                  CLIMATE_CHANGE 018:0480
# 6                         BIOMASS 018:0305
# 7                GREENHOUSE_GASES 017:0559
# 8                  DECISION_TREES 016:1848
# 9              ALTERNATIVE_ENERGY 014:1015
# 10                        BIOFUEL 014:0353
# 11           ENVIRONMENTAL_IMPACT 013:0351
# 12                 CARBON_DIOXIDE 012:0127
# 13             COST_EFFECTIVENESS 010:0302
# 14                  RANDOM_FOREST 010:0210
# 15  MACHINE_LEARNING_APPLICATIONS 010:0156
# 16                         CARBON 010:0125
# 17                  SUPPLY_CHAINS 010:0122
# 18                     LIFE_CYCLE 009:0512
# 19                  FUZZY_SYSTEMS 009:0355
#
#                                      CL_3  \
# 0                  DEEP_LEARNING 085:3444
# 1   ELECTRIC_AND_HYBRID_VEHICLES 040:1838
# 2              LITHIUM_BATTERIES 039:1027
# 3            CHARGING_STRATEGIES 031:1640
# 4                DIGITAL_STORAGE 024:0974
# 5     BATTERY_MANAGEMENT_SYSTEMS 022:0800
# 6                           IONS 021:0621
# 7                 ENERGY_STORAGE 019:0531
# 8            SECONDARY_BATTERIES 015:1025
# 9   CONVOLUTIONAL_NEURAL_NETWORK 014:0354
# 10     RECURRENT_NEURAL_NETWORKS 012:1022
# 11               STATE_OF_CHARGE 012:0611
# 12                  ELECTROLYTES 012:0435
# 13      RESEARCH_AND_DEVELOPMENT 011:0810
# 14              ELECTROCATALYSTS 011:0738
# 15              STATE_PREDICTION 011:0672
# 16            ELECTRIC_BATTERIES 010:0715
# 17                ENERGY_SOURCES 010:0662
# 18             ENERGY_CONVERSION 010:0638
# 19               STATE_OF_HEALTH 010:0569
#
#                                         CL_4
# 0                       WIND_ENERGY 049:2855
# 1                     WIND_TURBINES 026:1873
# 2                         FUEL_CELL 021:1515
# 3                    ENERGY_SYSTEMS 020:0967
# 4                     ENERGY_POLICY 013:0588
# 5              UNCERTAINTY_ANALYSIS 012:0386
# 6              CONDITION_MONITORING 010:0996
# 7                 NATURAL_RESOURCES 010:0446
# 8                           CELL_BE 010:0336
# 9               WEATHER_FORECASTING 009:0669
# 10                        WIND_FARM 009:0640
# 11              REGRESSION_ANALYSIS 009:0561
# 12               SOLID_ELECTROLYTES 007:0532
# 13  HYBRID_RENEWABLE_ENERGY_SYSTEMS 007:0481
# 14                            PEMFC 007:0379
# 15                             WIND 007:0228
# 16                 HYDROGEN_STORAGE 007:0085
# 17               OBJECTIVE_FUNCTION 006:0474
# 18                       WIND_SPEED 006:0469
# 19           ELECTRIC_POWER_SYSTEMS 006:0344
