# %% [markdown]
# # JSON DATA

# %%
import json

from techminer2.analyze.co_occurrence.network import communities_summary

data = {}

for year in range(2011, 2024):
    print(year)

    m = communities_summary(
        field="keywords",
        conserve_counters=False,
        occ_range=(2, None),
        algorithm_or_dict="louvain",
        association_index="association",
        root_dir="./",
        year_filter=(year, year),
    )
    m["Terms"] = m["Terms"].str.split("; ")
    m["Terms"] = m["Terms"].map(lambda x: [t.strip() for t in x[:10]])

    data[year] = {}
    for cluster in range(m.shape[0]):
        data[year][cluster] = m["Terms"][cluster]
print()
print(json.dumps(data, indent=4))
# Out:
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
#
# {
#     "2011": {
#         "0": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "WIND_ENERGY",
#             "WIND_TURBINES"
#         ]
#     },
#     "2012": {
#         "0": [
#             "PARTICLE_SWARM_OPTIMIZATION",
#             "MULTI_OBJECTIVE_OPTIMIZATION",
#             "OPTIMIZATION_PROBLEM",
#             "WIND_TURBINES"
#         ],
#         "1": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "METEOROLOGY"
#         ],
#         "2": [
#             "CARBON_DIOXIDE"
#         ]
#     },
#     "2013": {
#         "0": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "PHOTO_VOLTAIC_SYSTEM"
#         ]
#     },
#     "2014": {
#         "0": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "SOLAR_ENERGY",
#             "SOLAR_RADIATION",
#             "SOLAR_RADIATION_PREDICTION",
#             "METEOROLOGY"
#         ],
#         "1": [
#             "GENETIC_ALGORITHMS",
#             "PARTICLE_SWARM_OPTIMIZATION"
#         ]
#     },
#     "2015": {
#         "0": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "GENETIC_ALGORITHMS",
#             "SOLAR_ENERGY",
#             "SOLAR_RADIATION",
#             "SOLAR_RADIATION_PREDICTION",
#             "SOLAR_POWER_GENERATION",
#             "ERRORS",
#             "MEAN_SQUARE_ERROR",
#             "ROOT_MEAN_SQUARE_ERRORS",
#             "SUPPORT_VECTOR_MACHINES"
#         ],
#         "1": [
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "SMART_GRID",
#             "ENERGY_EFFICIENCY",
#             "ENERGY_UTILIZATION",
#             "GAS_EMISSIONS",
#             "GREENHOUSE_GASES",
#             "GREENHOUSE_GAS_EMISSIONS",
#             "COST_BENEFIT_ANALYSIS"
#         ],
#         "2": [
#             "MPPT",
#             "FUZZY_LOGIC",
#             "PERFORMANCE",
#             "CONTROLLERS",
#             "COMPUTER_CIRCUITS",
#             "ELECTRIC_INVERTERS"
#         ],
#         "3": [
#             "WIND_ENERGY",
#             "MATHEMATICAL_MODEL",
#             "PHOTO_VOLTAIC"
#         ]
#     },
#     "2016": {
#         "0": [
#             "DIGITAL_STORAGE",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "PERFORMANCE",
#             "DATA_MINING",
#             "ENERGY_STORAGE_SYSTEMS",
#             "ENERGY_MANAGEMENT_SYSTEMS",
#             "SMART_GRID"
#         ],
#         "1": [
#             "ENERGY",
#             "ENERGY_SOURCES",
#             "ENERGY_SYSTEMS",
#             "FUZZY_INFERENCE",
#             "GENETIC_ALGORITHMS"
#         ],
#         "2": [
#             "SOLAR_POWER_GENERATION",
#             "MEAN_SQUARE_ERROR",
#             "SOLAR_ENERGY",
#             "SOLAR_RADIATION"
#         ],
#         "3": [
#             "WIND_ENERGY",
#             "WIND_SPEED",
#             "WEIBULL_DISTRIBUTION"
#         ]
#     },
#     "2017": {
#         "0": [
#             "PARTICLE_SWARM",
#             "PARTICLE_SWARM_OPTIMIZATION",
#             "WIND_ENERGY",
#             "ENVIRONMENTAL_TECHNOLOGY",
#             "PERFORMANCE",
#             "MPPT",
#             "ENERGY",
#             "CUCKOO_SEARCH",
#             "COST_BENEFIT_ANALYSIS",
#             "COMPUTER_CIRCUITS"
#         ],
#         "1": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "FOSSIL_FUELS",
#             "ENERGY_POLICY",
#             "SOLAR_RADIATION",
#             "SOLAR_ENERGY",
#             "SOLAR_POWER_GENERATION",
#             "PHOTO_VOLTAIC",
#             "COMPLEX_NETWORKS"
#         ],
#         "2": [
#             "INVESTMENTS",
#             "ENERGY_UTILIZATION",
#             "CHARGING_STRATEGIES",
#             "ELECTRIC_AND_HYBRID_VEHICLES",
#             "GENETIC_ALGORITHMS",
#             "GREENHOUSE_GASES",
#             "GEOGRAPHIC_INFORMATION_SYSTEMS",
#             "CROP_ROTATION"
#         ],
#         "3": [
#             "MICRO_GRID",
#             "MULTI_AGENT_SYSTEMS",
#             "FUEL_CELL",
#             "WIND_TURBINES",
#             "OPTIMIZATION_AND_CONTROL"
#         ]
#     },
#     "2018": {
#         "0": [
#             "PHOTO_VOLTAIC_SYSTEM",
#             "FUZZY_LOGIC",
#             "SOLAR_PANELS",
#             "MPPT",
#             "COMPUTER_CIRCUITS",
#             "CONTROLLERS",
#             "DC_DC_CONVERTERS",
#             "BOOST_CONVERTER"
#         ],
#         "1": [
#             "WIND_ENERGY",
#             "FAULT_DETECTION",
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "WIND_TURBINES",
#             "PHOTO_VOLTAIC",
#             "SOLAR_CELLS",
#             "META_HEURISTIC_ALGORITHM"
#         ],
#         "2": [
#             "CHARGING_STRATEGIES",
#             "SOLAR_ENERGY",
#             "FOSSIL_FUELS",
#             "FUEL_CELL",
#             "MEAN_SQUARE_ERROR",
#             "SOLAR_RADIATION",
#             "GENETIC_ALGORITHMS"
#         ],
#         "3": [
#             "BIG_DATA",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "SMART_GRID",
#             "SCHEDULING"
#         ]
#     },
#     "2019": {
#         "0": [
#             "DECISION_MAKING",
#             "SMART_GRID",
#             "ELECTRIC_AND_HYBRID_VEHICLES",
#             "ENERGY_UTILIZATION",
#             "DEEP_LEARNING",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "SUPPORT_VECTOR_MACHINES",
#             "ENERGY_EFFICIENCY",
#             "ELECTRIC_POWER_SYSTEM_PLANNING",
#             "POWER_SYSTEM_PLANNING"
#         ],
#         "1": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "SOLAR_ENERGY",
#             "META_HEURISTIC_ALGORITHM",
#             "SOLAR_POWER_GENERATION",
#             "PARTICLE_SWARM_OPTIMIZATION",
#             "SOLAR_CELLS",
#             "HEURISTIC_ALGORITHMS",
#             "GENETIC_ALGORITHMS",
#             "ALTERNATIVE_ENERGY",
#             "DISTILLATION"
#         ],
#         "2": [
#             "GLOBAL_WARMING",
#             "ENERGY_MANAGEMENT",
#             "ENERGY_CONSERVATION",
#             "FOSSIL_FUELS",
#             "SUSTAINABLE_DEVELOPMENT",
#             "ENERGY_POLICY",
#             "SENSOR_NETWORKS",
#             "FUEL_ECONOMY"
#         ]
#     },
#     "2020": {
#         "0": [
#             "ENERGY_EFFICIENCY",
#             "OPTIMAL_CONTROL",
#             "ENERGY_MANAGEMENT",
#             "MICRO_GRID",
#             "ELECTRIC_AND_HYBRID_VEHICLES",
#             "GENETIC_ALGORITHMS",
#             "ENERGY_STORAGE",
#             "FUEL_CELL",
#             "OPTIMAL_CONTROL_SYSTEMS",
#             "ELECTRIC_POWER_SYSTEM_CONTROL"
#         ],
#         "1": [
#             "DEEP_LEARNING",
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "SUSTAINABLE_DEVELOPMENT",
#             "DECISION_MAKING",
#             "SMART_GRID",
#             "WIND_ENERGY",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "STOCHASTIC_SYSTEMS",
#             "UNCERTAINTY_ANALYSIS",
#             "REINFORCEMENT_LEARNING"
#         ],
#         "2": [
#             "ENERGY_UTILIZATION",
#             "BUILDINGS",
#             "PREDICTION_PERFORMANCE",
#             "SOLAR_ENERGY",
#             "BUILDING_ENERGY",
#             "ENERGY_CONSERVATION",
#             "CLIMATE_CHANGE",
#             "GREENHOUSE_GASES",
#             "CHEMICAL_ACTIVATION",
#             "HYBRID_MODEL"
#         ],
#         "3": [
#             "HEURISTIC_ALGORITHMS",
#             "PARAMETER_PREDICTION",
#             "META_HEURISTIC_ALGORITHM",
#             "SOLID_ELECTROLYTES",
#             "EVALUATION_CRITERIA",
#             "SOCIOLOGY",
#             "PEMFC",
#             "ELECTROCATALYSTS"
#         ],
#         "4": [
#             "CHARGING_STRATEGIES",
#             "PHYSICAL_MODEL",
#             "BATTERY_MANAGEMENT_SYSTEMS",
#             "SECONDARY_BATTERIES",
#             "STATE_OF_HEALTH",
#             "STATE_PREDICTION",
#             "DIGITAL_STORAGE"
#         ],
#         "5": [
#             "LITHIUM_BATTERIES",
#             "ENERGY_MATERIALS",
#             "OXYGEN",
#             "OXYGEN_EVOLUTION_REACTION",
#             "GRAPHENE",
#             "OXYGEN_REDUCTION_REACTION"
#         ]
#     },
#     "2021": {
#         "0": [
#             "DEEP_LEARNING",
#             "PHOTO_VOLTAIC_CELL",
#             "SOLAR_POWER_GENERATION",
#             "FAULT_DETECTION",
#             "PHOTO_VOLTAIC_SYSTEM",
#             "GENETIC_ALGORITHMS",
#             "SOLAR_ENERGY",
#             "WIND_TURBINES",
#             "PHOTO_VOLTAIC",
#             "MPPT"
#         ],
#         "1": [
#             "ENERGY_STORAGE",
#             "ELECTROCATALYSTS",
#             "HIGH_ENERGY_DENSITY",
#             "CATHODES",
#             "MORPHOLOGY",
#             "ENVIRONMENTAL_IMPACT",
#             "ELECTRODE_MATERIAL",
#             "ELECTRIC_BATTERIES",
#             "DEFECT_ENGINEERING",
#             "BATTERY_MATERIALS"
#         ],
#         "2": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "RECURRENT_NEURAL_NETWORKS",
#             "EFFICIENCY",
#             "SUPPORT_VECTOR_MACHINES",
#             "CONVOLUTIONAL_NEURAL_NETWORK",
#             "ADSORPTION",
#             "BIODIESEL",
#             "CARBON",
#             "LIFE_CYCLE",
#             "PROCESS_MONITORING"
#         ],
#         "3": [
#             "SMART_GRID",
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "DECISION_MAKING",
#             "FEATURE_EXTRACTION",
#             "POWER",
#             "DATA_HANDLING",
#             "ENERGY_PREDICTION",
#             "DIGITAL_STORAGE",
#             "ELECTRIC_POWER_SYSTEM_CONTROL",
#             "BIG_DATA"
#         ],
#         "4": [
#             "ENERGY_EFFICIENCY",
#             "ENERGY_UTILIZATION",
#             "ENERGY_MANAGEMENT",
#             "AI_TECHNOLOGY",
#             "INTERNET_OF_THINGS",
#             "INTELLIGENT_BUILDINGS",
#             "SMART_BUILDINGS",
#             "REINFORCEMENT_LEARNING",
#             "COMPUTER_CIRCUITS",
#             "FUZZY_LOGIC"
#         ],
#         "5": [
#             "LITHIUM_BATTERIES",
#             "IONS",
#             "LONG_SHORT_TERM_MEMORY_NETWORK",
#             "ACCURATE_PREDICTION",
#             "CHARGING_STRATEGIES",
#             "ANODES",
#             "MATERIAL_DESIGN",
#             "IONIC_CONDUCTION_IN_SOLIDS",
#             "PREDICTIVE_ANALYTICS",
#             "STOCHASTIC_SYSTEMS"
#         ],
#         "6": [
#             "ORGANIC_SOLAR_CELLS",
#             "PERFORMANCE_ASSESSMENT",
#             "DATA_SCIENCE",
#             "SOLAR_CELL_MATERIALS",
#             "SOLAR_POWER",
#             "PREDICTION_ACCURACY",
#             "POWER_CONVERSION_EFFICIENCIES"
#         ]
#     },
#     "2022": {
#         "0": [
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "WIND_ENERGY",
#             "GENETIC_ALGORITHMS",
#             "SUPPORT_VECTOR_MACHINES",
#             "SOLAR_POWER_GENERATION",
#             "PHOTO_VOLTAIC",
#             "ENERGY_SYSTEMS",
#             "PARTICLE_SWARM_OPTIMIZATION",
#             "SOLAR_ENERGY",
#             "META_HEURISTIC_ALGORITHM"
#         ],
#         "1": [
#             "ELECTRIC_POWER_TRANSMISSION_NETWORKS",
#             "SMART_GRID",
#             "ENERGY_EFFICIENCY",
#             "ENERGY_MANAGEMENT",
#             "REINFORCEMENT_LEARNING",
#             "ENERGY_UTILIZATION",
#             "ENERGY_MANAGEMENT_SYSTEMS",
#             "DECISION_MAKING",
#             "FOSSIL_FUELS",
#             "ENERGY"
#         ],
#         "2": [
#             "DEEP_LEARNING",
#             "LITHIUM_BATTERIES",
#             "ELECTRIC_AND_HYBRID_VEHICLES",
#             "CHARGING_STRATEGIES",
#             "IONS",
#             "BATTERY_MANAGEMENT_SYSTEMS",
#             "STATE_OF_CHARGE",
#             "DIGITAL_STORAGE",
#             "SECONDARY_BATTERIES",
#             "ELECTROLYTES"
#         ],
#         "3": [
#             "CELL_B_E",
#             "CELL_BE",
#             "ENERGY_CONVERSION",
#             "CLIMATE_CHANGE",
#             "RECENT_PROGRESS",
#             "POROSITY",
#             "ELECTROCATALYTIC",
#             "METALORGANIC_FRAMEWORKS",
#             "ELECTROCATALYSIS",
#             "POROUS_MATERIALS"
#         ],
#         "4": [
#             "ELECTRIC_UTILITIES",
#             "ENERGY_POLICY",
#             "OFFSHORE_OIL_WELL_PRODUCTION",
#             "OPERATION_AND_MAINTENANCE",
#             "INVESTMENTS",
#             "OFFSHORE_WIND_FARMS",
#             "WIND_CAPACITY",
#             "OFFSHORE_WINDS",
#             "WIND_FARM"
#         ]
#     },
#     "2023": {
#         "0": [
#             "LITHIUM_BATTERIES",
#             "SMART_GRID",
#             "ELECTRIC_AND_HYBRID_VEHICLES",
#             "ENERGY_EFFICIENCY",
#             "BATTERY_MANAGEMENT_SYSTEMS",
#             "REINFORCEMENT_LEARNING",
#             "CHARGING_STRATEGIES",
#             "DIGITAL_STORAGE",
#             "ENERGY_MANAGEMENT",
#             "INTERNET_OF_THINGS"
#         ],
#         "1": [
#             "SUPPORT_VECTOR_MACHINES",
#             "SUSTAINABLE_DEVELOPMENT",
#             "BIOMASS",
#             "BIOFUEL",
#             "SUPPLY_CHAINS",
#             "ENVIRONMENTAL_IMPACT",
#             "DECISION_TREES",
#             "BIOREFINERIES",
#             "GENETIC_ALGORITHMS",
#             "RANDOM_FOREST"
#         ],
#         "2": [
#             "DEEP_LEARNING",
#             "ARTIFICIAL_NEURAL_NETWORKS",
#             "SOLAR_ENERGY",
#             "SOLAR_POWER_GENERATION",
#             "WIND_ENERGY",
#             "ALTERNATIVE_ENERGY",
#             "PHOTO_VOLTAIC",
#             "NUMERICAL_MODEL",
#             "PHOTO_VOLTAIC_SYSTEM",
#             "CONVOLUTIONAL_NEURAL_NETWORK"
#         ],
#         "3": [
#             "OPTIMISATIONS",
#             "ENERGY_SYSTEMS",
#             "STORAGE_SYSTEMS",
#             "MICRO_GRID",
#             "ENERGY_UTILIZATION",
#             "PARTICLE_SWARM_OPTIMIZATION",
#             "ELECTRIC_ENERGY_STORAGE",
#             "FUZZY_INFERENCE",
#             "UNCERTAINTY_ANALYSIS",
#             "ENERGY_STORAGE"
#         ],
#         "4": [
#             "CARBON_DIOXIDE",
#             "CATALYSIS",
#             "HYDROGEN_PRODUCTION",
#             "HYDROGEN",
#             "REDUCTION_REACTION",
#             "HYDROGEN_STORAGE",
#             "CO_2_REDUCTION",
#             "ELECTROCATALYSIS",
#             "HYDROGEN_EVOLUTION_REACTION",
#             "HYDROGEN_SPILLOVER"
#         ],
#         "5": [
#             "FUEL_CELL",
#             "CELL_BE",
#             "CELL_B_E",
#             "PEROVSKITE_SOLAR_CELLS",
#             "PEROVSKITE",
#             "INTERPRETABLE_MACHINE_LEARNING",
#             "DURABILITY",
#             "CELL_RESEARCH",
#             "MATERIALS_DISCOVERY"
#         ],
#         "6": [
#             "FOSSIL_FUELS",
#             "HEAVY_METALS",
#             "PRE_TREATMENTS",
#             "BIOMASS_PRODUCTION",
#             "FORESTRY",
#             "LOW_EMITTANCE",
#             "SUSTAINABLE_PRODUCTION",
#             "WOODY_BIOMASS"
#         ]
#     }
# }
