# %%
from techminer2.co_occurrence.associations.keywords import network_graph

network_graph(
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(15, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # LAYOUT:
    nx_k=None,
    nx_iterations=20,
    nx_random_state=0,
    #
    # NODES:
    node_size_min=8,
    node_size_max=20,
    textfont_size_min=8,
    textfont_size_max=14,
    textfont_opacity_min=0.25,
    textfont_opacity_max=1.00,
    #
    # EDGES:
    edge_color="#E8E8E8",
    edge_width_min=0.7,
    edge_width_max=3.0,
    #
    # AXES:
    xaxes_range=None,
    yaxes_range=None,
    show_axes=False,
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).update_layout(width=1100, height=1100).show()
# Out:
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:298: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#
# /Volumes/GitHub/techminer2/techminer2/indicators/global_indicators_by_field.py:304: FutureWarning:
#
# The provided callable <function max at 0x1099ec9d0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
